# %% [markdown]
# # Análise consolidada de eventos LHE com pandas.DataFrame
#
# Notebook de trabalho para estudantes da disciplina FIS01214. Ele orienta uma análise completa do canal de Higgs em dois fótons. A análise percorre as Partes 1 e 2 usando `pandas.DataFrame` como estrutura principal, com células de código vazias. Use o Gemini no Colab para gerar, explicar e revisar o código de cada etapa antes de executá-lo.
#
# ## Ambientes suportados
#
# - Google Colab: faça upload do notebook e do ZIP do repositório, descompacte o projeto e infle os arquivos LHE conforme a seção 0.
# - CERN SWAN/Jupyter local: clone ou copie o repositório, instale as dependências e execute a partir da raiz do projeto.
#
# Dependências mínimas: `numpy`, `pandas`, PyROOT (`ROOT`) e `IPython`. Este notebook não depende de `pylhe`; a leitura é feita diretamente com Python e convertida para DataFrames.

# %% [markdown]
# ## Processo demonstrado
#
# Este exemplo usa as amostras de Higgs em dois fótons: sinal `pp → H → γγ` e fundo `pp → γγ` sem contribuição do Higgs. O objetivo é mostrar uma análise completa em nível de gerador, incluindo seleção, distribuições cinemáticas, massa invariante, normalização e interpretação das limitações detectoras.

# %%
# %jsroot on
print("JSROOT ativado: os canvases ROOT serão exibidos diretamente no notebook.")

# %% [markdown]
# # Projeto Final - Análise de eventos LHE - referência comentada
#
# ## Parte 1: Leitura do LHE para `pandas.DataFrame`
#
# Este notebook contem uma roteiro guiado para estudantes para a abordagem **pandas.DataFrame**.
# Ele inclui código completo e respostas de conferencia para a Parte 1.

# %% [markdown]
# ## 0. Preparação no Google Colab
#
# Antes de iniciar a análise, siga este fluxo no ambiente do Google Colab:
#
# 1. No GitHub, baixe o arquivo ZIP deste repositório (botão **Code → Download ZIP**) e baixe também o notebook desta tarefa que você vai executar.
# 2. Abra o notebook no Colab e use o painel **Arquivos** para fazer upload do arquivo `.ipynb` e do arquivo `.zip`. O ZIP deve ficar no mesmo ambiente de execução do notebook, como arquivo de dados.
# 3. Peça ao Gemini para gerar e executar um código que localize o ZIP enviado, descompacte o repositório no ambiente do Colab e entre na pasta extraída.
# 4. Em seguida, peça ao Gemini para gerar e executar um código que infle (descomprima com `gzip`) `data/sinal.lhe.gz` e `data/fundo.lhe.gz`, criando `data/sinal.lhe` e `data/fundo.lhe`. Mantenha os arquivos `.lhe.gz` originais.
# 5. Confirme com o agente que a pasta `data/` contém os dois arquivos compactados e as duas versões infladas antes de prosseguir.
#
# Depois dessa preparação, peça ao Gemini os códigos de cada etapa indicada neste notebook e copie-os nas células de código correspondentes. Use a pasta extraída como diretório de trabalho e mantenha os caminhos relativos aos arquivos de dados.
#
# > Nesta versão, peça ao Gemini para abrir diretamente os arquivos `.lhe.gz` com `gzip.open(..., "rt")`; não é necessário criar cópias `.lhe` descompactadas.
#
# **Motivação física e técnica.** Preparamos dependências, arquivos e caminhos para garantir uma análise reproduzível no Colab.

# %%
# !unzip /content/analise-colab.zip\n

# %% [markdown]
# ## Organização e roteiro
#
# O notebook segue os quatro itens de `parte1.txt`:
#
# 1. leitura dos arquivos LHE;
# 2. contagem dos eventos e tabela de partículas por `status`;
# 3. histogramas de $p_T$, $\eta$ e $\phi$ para as partículas finais visíveis;
# 4. estudo de cortes cinemáticos e reconstrução dos histogramas após a seleção.
#
# > Execute as células na ordem. O notebook localiza automaticamente a raiz do projeto quando é aberto a partir da pasta `notebooks/` ou da raiz do workdir.
#
# **Motivação física e técnica.** Cada bloco `<event>` representa uma colisão e contém partículas, códigos PDG e quadrimomentos; o roteiro transforma esses registros em observáveis físicos.

# %% [markdown]
# ### Etapa de código 1: peça o código ao Gemini\n\nPeça ao Gemini para gerar o código desta etapa com base nas instruções acima. Solicite uma explicação breve das decisões, cole o código na célula seguinte, execute-o e verifique se o resultado faz sentido fisicamente.\n

# %% [markdown]
# ## 1. Leitura dos arquivos LHE
#
# Um bloco `<event>` começa com uma linha de cabeçalho. O primeiro número dessa linha informa quantas partículas pertencem ao evento. Cada linha seguinte contém, entre outras informações, o identificador PDG, o `status`, as componentes do momento $(p_x,p_y,p_z)$, a energia e a massa.
#
# Usaremos `gzip.open` para ler os arquivos compactados sem criar cópias descompactadas.
#
# **Motivação física e técnica.** A leitura recupera $(E,p_x,p_y,p_z)$ e os identificadores PDG, que serão usados para construir grandezas cinemáticas.

# %% [markdown]
# ### Etapa de código 2: peça o código ao Gemini\n\nPeça ao Gemini para gerar o código desta etapa com base nas instruções acima. Solicite uma explicação breve das decisões, cole o código na célula seguinte, execute-o e verifique se o resultado faz sentido fisicamente.\n

# %% [markdown]
# ### Etapa de código 3: peça o código ao Gemini\n\nPeça ao Gemini para gerar o código desta etapa com base nas instruções acima. Solicite uma explicação breve das decisões, cole o código na célula seguinte, execute-o e verifique se o resultado faz sentido fisicamente.\n

# %% [markdown]
# ### Etapa de código 4: peça o código ao Gemini\n\nPeça ao Gemini para gerar o código desta etapa com base nas instruções acima. Solicite uma explicação breve das decisões, cole o código na célula seguinte, execute-o e verifique se o resultado faz sentido fisicamente.\n

# %% [markdown]
# ## 2a. Investigação preliminar do arquivo
#
# A célula anterior mostra o número de blocos `<event>` efetivamente lidos em cada amostra. Essa contagem deve coincidir com o número solicitado na geração do MadGraph.
#
# **Motivação física e técnica.** Validamos contagens e metadados antes de interpretar distribuições, evitando confundir arquivo incompleto com fenômeno físico.

# %% [markdown]
# ### Etapa de código 5: peça o código ao Gemini\n\nPeça ao Gemini para gerar o código desta etapa com base nas instruções acima. Solicite uma explicação breve das decisões, cole o código na célula seguinte, execute-o e verifique se o resultado faz sentido fisicamente.\n

# %% [markdown]
# ### Validação da integridade das amostras
#
# Antes de interpretar distribuições físicas, verificamos o número de partículas por evento (`NUP`), os os canais partônicos iniciais e a frequência da topologia final esperada. Valores não finitos, pesos inesperados ou eventos sem dois múons e dois partons $b$ devem ser investigados.

# %% [markdown]
# ### Etapa de código 6: peça o código ao Gemini\n\nPeça ao Gemini para gerar o código desta etapa com base nas instruções acima. Solicite uma explicação breve das decisões, cole o código na célula seguinte, execute-o e verifique se o resultado faz sentido fisicamente.\n

# %% [markdown]
# ## 2b. Investigação preliminar dos eventos
#
# No padrão LHE, os `status` usados aqui têm a seguinte interpretação:
#
# - `status = -1`: partícula inicial;
# - `status = 1`: partícula final estável no nível gerado;
# - `status = 2`: partícula intermediária cuja história foi preservada.
#
# A tabela conta tanto o número total de ocorrências quanto quantos eventos contêm cada combinação de partícula e `status`.
#
# **Motivação física e técnica.** Os estados inicial e final são distinguidos por `status` e PDG, revelando a topologia física do processo.

# %% [markdown]
# ### Etapa de código 7: peça o código ao Gemini\n\nPeça ao Gemini para gerar o código desta etapa com base nas instruções acima. Solicite uma explicação breve das decisões, cole o código na célula seguinte, execute-o e verifique se o resultado faz sentido fisicamente.\n

# %% [markdown]
# ### Identificação física das amostras
#
# Na amostra de **sinal**, os estados intermediários incluem o bóson de Higgs (`PDG 25`) e o bóson $Z$ (`PDG 23`). Seus decaimentos produzem $b\bar b$ e $\mu^+\mu^-$. Nem todos os eventos precisam exibir explicitamente ambos os intermediários no registro LHE, pois isso depende do canal/subprocesso e da forma como a história do evento foi gravada.
#
# Na amostra de **fundo**, o mesmo estado final $b\bar b\mu^+\mu^-$ é produzido sem exigir um Higgs intermediário. O $Z$ pode aparecer em diagramas ressonantes que originam o par de múons. Como sinal e fundo têm o mesmo estado final observável, a separação deve explorar diferenças nas distribuições cinemáticas.

# %% [markdown]
# ## 3. Exploração do conteúdo
#
# Selecionaremos partículas com `status = 1` e removeremos neutrinos (`|PDG| = 12, 14, 16`). Para cada partícula visível, calcularemos:
#
# $$p_T = \sqrt{p_x^2+p_y^2}, \qquad \eta = \operatorname{asinh}(p_z/p_T), \qquad \phi = \operatorname{atan2}(p_y,p_x).$$
#
# Os histogramas usarão exatamente os intervalos solicitados: $0<p_T<100$ GeV, $-3<\eta<3$ e $-\pi<\phi<\pi$.
#
# **Motivação física e técnica.** As distribuições de $p_T$, $\eta$ e $\phi$ mostram a ocupação do espaço de fase e antecipam a aceitação detectora.

# %% [markdown]
# ### Etapa de código 8: peça o código ao Gemini\n\nPeça ao Gemini para gerar o código desta etapa com base nas instruções acima. Solicite uma explicação breve das decisões, cole o código na célula seguinte, execute-o e verifique se o resultado faz sentido fisicamente.\n

# %% [markdown]
# ### Etapa de código 9: peça o código ao Gemini\n\nPeça ao Gemini para gerar o código desta etapa com base nas instruções acima. Solicite uma explicação breve das decisões, cole o código na célula seguinte, execute-o e verifique se o resultado faz sentido fisicamente.\n

# %% [markdown]
# ### Etapa de código 10: peça o código ao Gemini\n\nPeça ao Gemini para gerar o código desta etapa com base nas instruções acima. Solicite uma explicação breve das decisões, cole o código na célula seguinte, execute-o e verifique se o resultado faz sentido fisicamente.\n

# %% [markdown]
# ### Etapa de código 11: peça o código ao Gemini\n\nPeça ao Gemini para gerar o código desta etapa com base nas instruções acima. Solicite uma explicação breve das decisões, cole o código na célula seguinte, execute-o e verifique se o resultado faz sentido fisicamente.\n

# %% [markdown]
# ### Os histogramas representam todos os eventos?
#
# Não necessariamente. Há quatro motivos possíveis:
#
# 1. uma espécie de partícula pode não aparecer em todos os eventos;
# 2. um evento pode conter mais de uma partícula da mesma espécie, produzindo mais entradas do que eventos;
# 3. neutrinos e partículas com `status != 1` foram removidos por definição;
# 4. uma partícula pode existir no evento, mas ficar fora do intervalo fixado para o histograma — especialmente $p_T>100$ GeV ou $|\eta|>3$.
#
# Por isso, a tabela acima apresenta separadamente o número de **entradas** e o número de **eventos representados** em cada intervalo.

# %% [markdown]
# ### Etapa de código 12: peça o código ao Gemini\n\nPeça ao Gemini para gerar o código desta etapa com base nas instruções acima. Solicite uma explicação breve das decisões, cole o código na célula seguinte, execute-o e verifique se o resultado faz sentido fisicamente.\n

# %% [markdown]
# ### Variáveis em nível de evento
#
# Uma análise do LHC também organiza os objetos dentro de cada evento. A seguir distinguimos objetos líderes e sublíderes em $p_T$ e calculamos $\Delta\eta$, $\Delta\phi$ e $\Delta R=\sqrt{(\Delta\eta)^2+(\Delta\phi)^2}$ para os pares de múons e de partons $b$.

# %% [markdown]
# ### Etapa de código 13: peça o código ao Gemini\n\nPeça ao Gemini para gerar o código desta etapa com base nas instruções acima. Solicite uma explicação breve das decisões, cole o código na célula seguinte, execute-o e verifique se o resultado faz sentido fisicamente.\n

# %% [markdown]
# ### Etapa de código 14: peça o código ao Gemini\n\nPeça ao Gemini para gerar o código desta etapa com base nas instruções acima. Solicite uma explicação breve das decisões, cole o código na célula seguinte, execute-o e verifique se o resultado faz sentido fisicamente.\n

# %% [markdown]
# ## 4. Seleção cinemática e cutflow
#
# Aplicaremos cortes sequenciais e diferentes por tipo de objeto. Para os múons, usamos $p_T>20$ GeV e $|\eta|<2{,}4$. Para os partons $b$, tratados apenas como aproximação de jatos em nível de gerador, usamos $p_T>25$ GeV e $|\eta|<2{,}5$. Por fim, exigimos $\Delta R>0{,}4$ em cada par. Esses valores são ilustrativos e não substituem uma seleção completa do CMS ou ATLAS.
#
# A tabela de cutflow mostrará as eficiências incrementais e acumuladas. A razão $\epsilon_S/\epsilon_B$ mede apenas o ganho relativo da seleção; ela **não é uma significância estatística**.
#
# **Motivação física e técnica.** Os cortes aumentam a pureza da amostra. O cutflow acompanha a fração $N_i/N_{i-1}$ sobrevivente em cada requisito.

# %% [markdown]
# ### Etapa de código 15: peça o código ao Gemini\n\nPeça ao Gemini para gerar o código desta etapa com base nas instruções acima. Solicite uma explicação breve das decisões, cole o código na célula seguinte, execute-o e verifique se o resultado faz sentido fisicamente.\n

# %% [markdown]
# ### Etapa de código 16: peça o código ao Gemini\n\nPeça ao Gemini para gerar o código desta etapa com base nas instruções acima. Solicite uma explicação breve das decisões, cole o código na célula seguinte, execute-o e verifique se o resultado faz sentido fisicamente.\n

# %% [markdown]
# ## 5. Conclusões da Parte 1
#
# - As duas amostras possuem o mesmo estado final em nível de gerador: $b\bar b\mu^+\mu^-$.
# - A amostra de sinal contém a produção associada de $H$ e $Z$; o fundo produz o mesmo estado final sem exigir um Higgs intermediário.
# - O $p_T$ dos partons $b$ é uma das variáveis mais úteis nesta amostra: o fundo contínuo apresenta partons $b$ mais suaves e mais à frente.
# - O cutflow permite identificar qual requisito rejeita mais fundo e qual é o custo acumulado em eficiência do sinal.
# - Os resultados são partônicos. Uma análise experimental exigiria hadronização, reconstrução de jatos, identificação de $b$, eficiências, resolução e demais efeitos do detector.
# - A normalização por seção de choque e luminosidade, assim como $S/B$ e $S/\sqrt{B}$, pertence à Parte 2.
#
# **Motivação física e técnica.** Consolidamos o que foi observado no LHE e após a seleção, preparando a interpretação estatística da Parte 2.

# %% [markdown]
# ### Etapa de código 17: peça o código ao Gemini\n\nPeça ao Gemini para gerar o código desta etapa com base nas instruções acima. Solicite uma explicação breve das decisões, cole o código na célula seguinte, execute-o e verifique se o resultado faz sentido fisicamente.\n

# %% [markdown]
# ## Exercício: respostas e interpretação\n\nPeça ao Gemini para ajudar a calcular e interpretar os resultados desta etapa a partir das tabelas e gráficos produzidos.\nNão aceite números prontos: execute o código, confira as contagens e explique as diferenças entre sinal e fundo com suas próprias palavras.

# %% [markdown]
# # Parte 2 — conservação, massas e normalização
#
# A seguir, a análise continua com as grandezas físicas e a normalização da Parte 2, mantendo a abordagem baseada em DataFrame.
#
# **Motivação física e técnica.** Relacionamos eventos observados à produção física por $N=\sigma\,\mathcal{L}\,A\,arepsilon$, reconstruindo candidatos e normalizando as amostras.

# %% [markdown]
# ### Luminosidade adotada no início da Parte 2
#
# Defina a luminosidade integrada usada na normalização e na estimativa da seção de choque. As ferramentas e os arquivos LHE já foram preparados anteriormente.
#
# **Peça a um agente para confirmar o valor e o código desta configuração.**

# %%
# Cole aqui o código fornecido pelo agente para definir a luminosidade.

# %% [markdown]
# ### Etapa de código 18: peça o código ao Gemini\n\nPeça ao Gemini para gerar o código desta etapa com base nas instruções acima. Solicite uma explicação breve das decisões, cole o código na célula seguinte, execute-o e verifique se o resultado faz sentido fisicamente.\n

# %% [markdown]
# ## Emulação e comparação antes/depois da eficiência
#
# Peça ao Gemini para gerar a aplicação de uma eficiência reprodutível às partículas e três comparações (sinal e fundo) de $p_T$, $\eta$ e $\phi$ antes/depois. Organize cada figura com o histograma no painel superior e a razão depois/antes no painel inferior.
#
# **Motivação física e técnica.** A eficiência $arepsilon(p_T,\eta)$ é a probabilidade de reconstrução; comparar antes/depois mostra como a resposta detectora modifica as distribuições.

# %%
# Cole aqui o código fornecido pelo Gemini para esta etapa.

# %% [markdown]
# ## 1. Leitura, metadados e seleção da Parte 1
#
# **Motivação física e técnica.** Recuperamos $\sigma$ e os eventos já lidos. O bloco `<init>` fornece a escala física usada na normalização.

# %% [markdown]
# ### Etapa de código 19: peça o código ao Gemini\n\nPeça ao Gemini para gerar o código desta etapa com base nas instruções acima. Solicite uma explicação breve das decisões, cole o código na célula seguinte, execute-o e verifique se o resultado faz sentido fisicamente.\n

# %% [markdown]
# ### Etapa de código 20: peça o código ao Gemini\n\nPeça ao Gemini para gerar o código desta etapa com base nas instruções acima. Solicite uma explicação breve das decisões, cole o código na célula seguinte, execute-o e verifique se o resultado faz sentido fisicamente.\n

# %% [markdown]
# ## 2. Conservação do quadrimomento e $\hat{s}$
#
# **Motivação física e técnica.** Testamos $\sum p^\mu_{
# m inicial}pprox\sum p^\mu_{
# m final}$ e calculamos $\hat{s}=(p_1+p_2)^2$.

# %% [markdown]
# ### Etapa de código 21: peça o código ao Gemini\n\nPeça ao Gemini para gerar o código desta etapa com base nas instruções acima. Solicite uma explicação breve das decisões, cole o código na célula seguinte, execute-o e verifique se o resultado faz sentido fisicamente.\n

# %% [markdown]
# ## 3. Massas invariantes e histogramas 2D
#
# **Motivação física e técnica.** Calculamos $m^2=(\sum E)^2-|\sumec p|^2$ e estudamos correlações em histogramas 2D.

# %% [markdown]
# ### Etapa de código 22: peça o código ao Gemini\n\nPeça ao Gemini para gerar o código desta etapa com base nas instruções acima. Solicite uma explicação breve das decisões, cole o código na célula seguinte, execute-o e verifique se o resultado faz sentido fisicamente.\n

# %% [markdown]
# ## 4. Pesos, seção de choque e luminosidade
#
#
# Os histogramas normalizados usam o peso físico $w=\sigma\,L/N_{\mathrm{gerado}}$ para comparar sinal e fundo na mesma luminosidade.
#
# **Motivação física e técnica.** Cada evento recebe $w=\sigma\mathcal{L}/N_{
# m gerado}$, convertendo a simulação em yield esperado.

# %% [markdown]
# ### Etapa de código 23: peça o código ao Gemini\n\nPeça ao Gemini para gerar o código desta etapa com base nas instruções acima. Solicite uma explicação breve das decisões, cole o código na célula seguinte, execute-o e verifique se o resultado faz sentido fisicamente.\n

# %% [markdown]
# ## 5. Histogramas empilhados normalizados
#
# **Motivação física e técnica.** O empilhamento compara composição de sinal e fundo na mesma luminosidade.

# %% [markdown]
# ### Etapa de código 24: peça o código ao Gemini\n\nPeça ao Gemini para gerar o código desta etapa com base nas instruções acima. Solicite uma explicação breve das decisões, cole o código na célula seguinte, execute-o e verifique se o resultado faz sentido fisicamente.\n

# %% [markdown]
# ## 6. Estimativa simplificada da seção de choque
#
# **Motivação física e técnica.** Usamos $\hat{\sigma}=N_{
# m pass}/(Aarepsilon\mathcal{L})$ para relacionar contagem selecionada e produção física.

# %% [markdown]
# ### Etapa de código 25: peça o código ao Gemini\n\nPeça ao Gemini para gerar o código desta etapa com base nas instruções acima. Solicite uma explicação breve das decisões, cole o código na célula seguinte, execute-o e verifique se o resultado faz sentido fisicamente.\n

# %% [markdown]
# ## Respostas de referência verificadas nas amostras
#
# Estes valores foram calculados diretamente de `sinal.lhe.gz` e `fundo.lhe.gz`
# com `L = 10/fb = 10000/pb`.
#
# - Seção de choque do sinal: aproximadamente `0.01021435 pb`.
# - Seção de choque do fundo: aproximadamente `26.1445 pb`.
# - Yield total esperado antes de cortes: `102.1435` eventos de sinal e
#   `261445` eventos de fundo.
# - Após a seleção da Parte 1: `5335` eventos de sinal e `412` eventos de fundo
#   de Monte Carlo passam.
# - Yields esperados após seleção: cerca de `54.49` eventos de sinal e
#   `10771.53` eventos de fundo.
# - $S/B$ após seleção: aproximadamente `0.00506`.
# - $S/\sqrt{B}$ após seleção: aproximadamente `0.525`.
#
# A estimativa simplificada
#
# ```text
# sigma_estimado = N / ((N_pass/N_gerado) * L)
# ```
#
# recupera a seção de choque do LHE quando `N` e o yield esperado construido a
# partir da propria simulação. Para o sinal, a inversao retorna aproximadamente
# `0.01021435 pb`; para o fundo, retorna aproximadamente `26.1445 pb`. Isso e uma
# checagem de consistencia da normalização, não uma medida experimental
# independente.
#
# Nos eventos de teste `1 + 1000*i`, os resíduos maximos de conservação de
# quadrimomento ficam da ordem de `10^-8 GeV` para o sinal e `10^-9 GeV` para o
# fundo, compatíveis com precisao numérica.
#
# As massas invariantes mostram uma estrutura clara em `m_mumu` perto da massa do
# `Z` tanto no sinal quanto no fundo. No sinal, `m_bb` tem mediana perto de
# `125 GeV`, consistente com o Higgs. No fundo continuo, `m_bb` e muito mais
# espalhada e tem mediana perto de `52.5 GeV`.
#
# A normalização mostra que, apesar da seleção rejeitar fortemente o fundo em
# eficiência, a seção de choque do fundo e muito maior. Por isso a amostra
# normalizada ainda e dominada por fundo. Uma análise mais realista precisaria de
# subtracao de fundo em dados, hadronizacao, reconstrucao de jatos, identificação
# de `b`, eficiências, resolucao do detector, pileup e trigger.
#
# **Motivação física e técnica.** Cada resposta deve ser justificada por uma contagem, seleção ou fórmula definida anteriormente.
